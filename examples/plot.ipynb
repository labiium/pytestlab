# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load("data_sweep.npy")

plt.figure(figsize=(10, 6))  # Adjust figure size as needed

print(data.shape)
print(data[0, 0, :])
for i in range(len(data)):
    plt.plot(data[i, :, 0], data[i, :, 2], label=f"Data {data[i, 0, 1]}")

plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")
plt.title("Data Sweep")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# (10, 100, 3)
# [0.00000000e+00 5.00000000e+00 1.89516842e-03]
